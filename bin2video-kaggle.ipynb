# %%
#Donload Application
# !wget -O bin2video https://github.com/kannoun/bin2video_kaggle/raw/refs/heads/main/bin2video
# !chmod +x bin2video
#install ffmpeg
# !apt-get update -y
# !apt install -y ffmpeg

# %%
#download input/output file
# !wget -O v.zip https://l.station307.com/Dgr6wLFVjuHKQKUec3DA5R/v.zip

# %%
#encoding --c:v to use GPUs
# !./bin2video -e -s 4 -f 60 -i v.zip -o output.mp4 -- -c:v h264_nvenc -preset p6 -cq 23 #-- -c:v hevc_nvenc -preset p6 -cq 25

# %%
#Decoding
# !./bin2video -d -i output.mp4 -o t.7z -- -c:v h264_nvenc -preset p6 -cq 23

# %%
#test archive
!7z t t.7z
